# %%
a = ["A", "B", "C"]
b = [1, 2, 3]
c = {'Alphabets': a, "Numerics": b}
print(c)
# Out:
# {'Alphabets': ['A', 'B', 'C'], 'Numerics': [1, 2, 3]}

# %%
c['Numerics']
# Out:
# [1, 2, 3]

# %%
c["Alphabets"]
# Out:
# ['A', 'B', 'C']
